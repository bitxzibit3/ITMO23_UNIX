# %% [markdown]
# # Лабораторная работа №4. Халимов Тимур, К3332.

# %% [markdown]
# ## Задача 1
# Последовательные вычисления.
# Требуется последовательно выполнить вычисления по формуле 1, вычисления по формуле 2, после чего выполнить вычисления по формуле 3, которые выглядят следующим образом: результат вычислений 1 + результат вычислений 2 – результат вычислений 1
#
# Выполнить последовательно на 10 000 итераций и 100 000 итераций
#
# Формула 1: f(x) = x ^2- x ^2+ x *4- x *5+ x + x
#
# Формула 2: f(x) = x + x
#
# Вывести длительность выполнения всех 10 000 итераций и 100 000 итераций в сек.

# %% [markdown]
# Таким образом осуществляется подсчет функций при последовательном выполнении:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Задача 2
# Параллельные вычисления через потоки.
# Требуется параллельно (с помощью потоков) выполнить вычисления по формуле 1, вычисления по формуле 2, после чего выполнить вычисления по формуле 3, которые выглядят следующим образом: результат вычислений 1 + результат вычислений 2 – результат вычислений 1
#
# Выполнить последовательно на 10 000 итераций и 100 000 итераций
#
# Формула 1: f(x) = x ^2- x ^2+ x *4- x *5+ x + x
#
# Формула 2: f(x) = x + x
#
# Вывести длительность выполнения всех 10 000 итераций и 100 000 итераций в сек.

# %% [markdown]
# Таким образом осуществляется подсчет функций при параллельном выполнении через потоки:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Задача 3
# Параллельные вычисления через процессы.
# Требуется параллельно (с помощью процессов) выполнить вычисления по формуле 1, вычисления по формуле 2, после чего выполнить вычисления по формуле 3, которые выглядят следующим образом: результат вычислений 1 + результат вычислений 2 – результат вычислений 1
#
# Выполнить последовательно на 10 000 итераций и 100 000 итераций
#
# Формула 1: f(x) = x ^2- x ^2+ x *4- x *5+ x + x
#
# Формула 2: f(x) = x + x
#
# Вывести длительность выполнения всех 10 000 итераций и 100 000 итераций в сек.

# %% [markdown]
# Таким образом осуществляется подсчет функций при параллельном выполнении через процессы:
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Для каждого типа вычислений было проведено по 1000 вычислений, после чего значение времени на итерацию было усреднено.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### То же самое, только в табличке
# Iterations| Sequence | Threads | Processes |
# ----------|----------|---------|-----------|
# 10000     | 0.000166    | 0.000116   | 0.000516   |
# 100000    | 0.000542    | 0.001976   | 0.001184   |
# 1000000   | 0.004879    | 0.014506   | 0.007763   |
